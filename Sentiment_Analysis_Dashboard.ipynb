# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Machine-Learning-Intern-Projects/blob/main/Sentiment_Analysis_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob

from textblob import TextBlob

text="This project is amazing"

result=TextBlob(text)

print(
result.sentiment
)
# Out:
# ...
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
