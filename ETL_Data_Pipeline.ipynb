# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Machine-Learning-Intern-Projects/blob/main/ETL_Data_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

import pandas as pd

# Extract
data = pd.DataFrame({
"Sales":[100,200,300],
"Profit":[20,50,70]
})

# Transform
data["Margin"]=data["Profit"]/data["Sales"]

# Load
data.to_csv("clean_data.csv",index=False)

print(data)
# Out:
# ...
#    Sales  Profit    Margin
# 0    100      20  0.200000
# 1    200      50  0.250000
# 2    300      70  0.233333
