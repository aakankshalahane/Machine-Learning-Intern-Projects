# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Machine-Learning-Intern-Projects/blob/main/Real_Time_Data_Streaming_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random

for i in range(5):

    value=random.randint(
        0,
        100
    )

    print(
        "Live Data:",
        value
    )

    time.sleep(1)
# Out:
# Live Data: 78
# Live Data: 47
# Live Data: 85
# Live Data: 75
# Live Data: 2
